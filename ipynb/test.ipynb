# %%
import analysis_lib as al
from pathlib import Path
import pandas as pd

pp_path = Path("/home/decwest/decwest_workspace/dwpp_test_simulation/data/real_robot_experiment/PathC/PP/dynamic_window_pure_pursuit_log_20251229_191700_290890158.csv")
app_path = Path("/home/decwest/decwest_workspace/dwpp_test_simulation/data/real_robot_experiment/PathC/APP/dynamic_window_pure_pursuit_log_20251229_192910_153979043.csv")
rpp_path = Path("/home/decwest/decwest_workspace/dwpp_test_simulation/data/real_robot_experiment/PathC/RPP/dynamic_window_pure_pursuit_log_20251229_193402_495246922.csv")
dwpp_path = Path("/home/decwest/decwest_workspace/dwpp_test_simulation/data/real_robot_experiment/PathC/DWPP/dynamic_window_pure_pursuit_log_20251229_194423_299209716.csv")
al.analyze_single_csv(pp_path, "PathC", "PP")
al.analyze_single_csv(app_path, "PathC", "APP")
al.analyze_single_csv(rpp_path, "PathC", "RPP")
al.analyze_single_csv(dwpp_path, "PathC", "DWPP")
# Out:
#  Velocity violation rate: 53.01%
#  RMSE to PathC of PP: 0.3104 m
#  Travel time of PP: 23.23 s
#  Velocity violation rate: 34.06%
#  RMSE to PathC of APP: 0.2572 m
#  Travel time of APP: 21.50 s
#  Velocity violation rate: 34.40%
#  RMSE to PathC of RPP: 0.1366 m
#  Travel time of RPP: 24.00 s
#  Velocity violation rate: 0.00%
#  RMSE to PathC of DWPP: 0.1022 m
#  Travel time of DWPP: 24.60 s

# %%
al.plot_path([pp_path, app_path, rpp_path, dwpp_path], "PathC", ["PP", "APP", "RPP", "DWPP"])
